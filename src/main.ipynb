# %%
from dotenv import load_dotenv

load_dotenv()
# Warning control
import warnings

warnings.filterwarnings("ignore")

# %%
from crewai import Agent, Task, Crew, Process
from crewai_tools import tools
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from openai import OpenAI
import os, requests

# %%
llm1 = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash", google_api_key=os.getenv("GEMINI_API_KEY")
)
llm = ChatOpenAI(model="gpt-3.5-turbo", api_key=os.getenv("GPT_API_KEY"))

# %% [markdown]
# # ImageGenerate

# %%
def generateimage(chapter_content):
    client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

    response = client.images.generate(
        model="dall-e-3",
        prompt=f"이미지의 내용: {chapter_content}. Style: Illustration. Create an illustration incorporating a vivid palette with an emphasis on shades of azure and emerald, augmented by splashes of gold for contrast and visual interest. The style should evoke the intricate detail and whimsy of early 20th-century storybook illustrations, blending realism with fantastical elements to create a sense of wonder and enchantment. The composition should be rich in texture, with a soft, luminous lighting that enhances the magical atmosphere. Attention to the interplay of light and shadow will add depth and dimensionality, inviting the viewer to delve into the scene. DON'T include ANY text in this image. DON'T include colour palettes in this image.",
        size="1024x1024",
        quality="standard",
        n=1,
    )

    image_url = response.data[0].url
    filename = f"image_{chapter_content[:10].replace(' ', '_')}.png"
    filepath = os.path.join(os.path.dirname(os.getcwd()), "img", filename)

    image_response = requests.get(image_url)
    if image_response.status_code == 200:
        with open(filepath, "wb") as file:
            file.write(image_response.content)
    else:
        print("Failed to download the image.")
        return ""

    return filepath

# %%
class ImageGeneratorAgent(Agent):
    print("여기가 오류입니다. 1")

    def execute(self, chapter_content):
        image_path = generateimage(chapter_content)
        print(f"이미지 저장 위치 : {image_path}")
        return image_path
# Out:
# 여기가 오류입니다. 1

# %% [markdown]
# # Agent

# %%
story_agent = Agent(
    role="이야기 생성자",
    goal="{theme} 배경으로 흥미로운 상황을 생성합니다.",
    backstory="당신은 유명한 작가입니다."
    "사용자의 요구에 맞게 자연스럽게 흥미로운 이야기를 만들어 낼 수 있습니다."
    "현제 롤플레잉을 하고 있습니다, 이야기를 만들어 나갈 때 주인공의 행동을 당신이 결정해서는 안됩니다. ",
    memory=True,
    allow_delegation=False,
    llm=llm1,
)

# 선택지 에이전트: 상황에 맞는 4가지 선택지를 제공
# 추가로 종료 선택지와, 자유롭게 입력하는 것도 허용
choice_agent = Agent(
    role="선택지 제공자",
    goal="주어진 상황을 보고 주인공이 행동할 5가지 선택지를 생성합니다.",
    backstory="당신은 상황에 맞게 선택지를 제시하는 역할을 맡고 있습니다."
    "이야기의 주인공이 당신의 선택지 중 하나를 선택할 것입니다. "
    "선택지간 다른 이야기가 전개될 수 있도록 선택지를 생성하세요. ",
    memory=True,
    allow_delegation=False,
    llm=llm1,
)

# 이미지 생성 에이전트 정의
image_generator_agent = Agent(
    role="이미지 생성기",
    goal="이야기에 맞는 이미지를 생성합니다.",
    memory=True,
    backstory="당신은 이야기의 이미지를 생성하는 전문 AI입니다.",
    allow_delegation=False,
    llm=llm1,
)

# 결말 에이전트
ending_agent = Agent(
    role="이야기 결말 생성자",
    goal="주어진 이야기를 보고 결말을 내립니다.",
    backstory=" 많은 사람이 납득가능하게 이야기를 마무리 할 수 있습니다. ",
    memory=True,
    allow_delegation=False,
    llm=llm1,
)

# 주인공 생성 에이전트
create_player_agent = Agent(
    role="이야기의 주인공 생성자",
    goal="{theme} 배경에 어울리는 인물 한 명을 생성합니다. ",
    backstory="사람에 대해 자새하게 묘사할 수 있습니다.",
    memory=True,
    allow_delegation=False,
    llm=llm1,
)


# summerize_agent = Agent(
#     role='내용 요약자',
#     goal='주어진 내용을 읽고 주요 내용을 요약하세요',
#     memory=True,
#     backstory='당신은 내용을 읽고 요약하는 역할을 맡고 있습니다.',
#     allow_delegation=False,
#     llm=llm1
# )

# %% [markdown]
# # Tasks

# %%
# 이야기 생성 작업
story_creation_task = Task(
    description=(
        "1. 나열된 규칙을 지키면서 {theme} 배경에 자연스럽고 {previous_story}에 이어지는 새로운 상황을 생성하세요.\n"
        "규칙 1. 주인공의 선택을 마음대로 결정해서는 안됩니다.\n"
        "규칙 2. 주인공이 처한 상황, 다른 인물이 걸어오는 대사 등을 포함합니다.\n"
        "규칙 3. 이야기는 주인공이 어떤 선택을 해야 할 상황에서 끝나도록 하세요.\n"
        "규칙 4. 주인공이 어떤 행동을 할지 질문하거나 궁금해하지 말고, 주인공의 결정을 요구하는 문장 없이 스토리만 생성합니다.\n"
        "규칙 5. 상황을 마무리하는 문장으로 질문이나 선택을 요구하는 문장이 포함되지 않도록 하세요."
    ),
    expected_output=(
        "200글자 내외의 흥미로운 상황이 생성됩니다.\n" "반드시 한국어로 생성하세요."
    ),
    agent=story_agent,
)


# 선택지 생성 작업
# 필요하면 추가 : "선택지는 1.~ 2.~ 3.~ 4.~ 순으로 제공되고 선택지마다 줄바꿈을 해서 출력하세요"
choice_creation_task = Task(
    description="이야기 상황에 맞는 4가지 선택지를 생성하세요. 각 선택지는 이야기와 관련이 있어야 합니다."
    "{previous_story}와 이어지며, 마지막으로 제시된 상황에 맞는 선택지를 생성하세요. \n"
    "5번째 선택지는 고정적으로 '여기서 이야기의 마무리합니다.'입니다.",
    expected_output="상황에 맞는 4가지 선택지가 생성됩니다.\n"
    "모든 선택지 앞에 1. 2. 3. 4. 같이 숫자를 붙이세요\n"
    "각 선텍지는 줄바꿈 하여 출력하세요",
    agent=choice_agent,
)

# 이미지 생성 작업
task_image_generation = Task(
    description="이야기 내용에 따라 이미지를 생성합니다.",
    agent=image_generator_agent,
    expected_output="생성된 이미지를 반환합니다.",
)


# 이야기 결말 작업
ending_task = Task(
    description="{previous_story}에 이어지는 결말을 생성하세요"
    "이야기가 마무리되는 느낌으로 되어야 합니다. "
    "'나의 이야기는 이제부터 시작될 것이다.' 등과 같이 새로운 이야기를 암시하는 내용은 포함하지 않습니다. ",
    expected_output="줄글의 형식으로 생성하세요." "반드시 한국어로 생성하세요.",
    agent=ending_agent,
)


# 주인공 생성 작업
create_player_task = Task(
    description="{theme} 배경에 어울리는 인물 한명을 생성합니다. "
    "우선 그 인물의 직업을 5개정도 생성하고 무작위로 하나를 선택합니다. "
    "그 인물의 인적사항을 출력합니다",
    expected_output="당신은 '(직업)'입니다'로 시작해서 인적사항을 적습니다.",
    agent=create_player_agent,
)


# story_summerization_task = Task(
#     description= '{previous_story}를 읽고 내용을 요약하세요'
#                  '글은 이야기, 선택지, 사용자 선택으로 나누어져있습니다. 이야기에 맞춰 사용자가 선택한 선택지를 참고하여 내용을 요약하세요'
#                  '중요 내용을 판단하여 요약합니다.',
#     expected_output='주어진 글을 읽고 내용을 요약하세요',
#     agent=summerize_agent
# )

# %% [markdown]
# # Crew

# %%
story_crew = Crew(
    agents=[
        story_agent,
        choice_agent,
        ending_agent,
        create_player_agent,
        # summerize_agent
    ],
    tasks=[
        story_creation_task,
        choice_creation_task,
        ending_task,
        create_player_task,
        # story_summerization_task
    ],
    process=Process.sequential,
    verbose=True,
)

# %%
def execute_story(
    crew,
    theme,
    logfile="log.md",
    storyfile="story.md",
    # summary = 'summary.md',
    # generated_story = 'generated_story.md'
):

    # 플레이어 생성
    crew.tasks = [create_player_task]
    player_info = crew.kickoff(inputs={"theme": theme, "previous_story": ""}) + "\n"

    # 플레이어 정보가 든 파일 생성
    # 스토리만
    with open(storyfile, "w", encoding="utf-8") as file:
        file.write(player_info)
    # 스토리와 선택지 포함해서 모든 정보 저장
    with open(logfile, "w", encoding="utf-8") as file:
        file.write(player_info)

    for i in range(9):

        # 요약을 읽기 / 이야기 생성 / 문장 저장
        story_result = story_creation(crew, theme, storyfile, logfile, i)

        # 이미지 생성 부분 result가 파일 위치
        # result = generateimage(story_result)

        # 선택지 생성 / 선택지 내용 저장
        choices_creation = create_options(crew, theme, storyfile, logfile)

        # 사용자 선택 / 선택한 내용 저장
        continue_story = user_selection(choices_creation, storyfile, logfile, i)

        if not continue_story:
            with open(storyfile, "r", encoding="utf-8") as file:
                previous_story = file.read()

            # 이야기 생성
            crew.tasks = [ending_task]

            story_result = crew.kickoff(
                inputs={"theme": theme, "previous_story": previous_story}
            )
            story_result = f"## 마지막 이야기 :\n{story_result}\n\n"

            # 이야기 내용을 파일에 저장
            with open(storyfile, "a", encoding="utf-8") as file:
                file.write(story_result)

            # 로그 기록
            with open(logfile, "a", encoding="utf-8") as file:
                file.write(story_result)

            break

        # 내용 가져오기 / 내용 요약 / 요약 파일 누적 저장
        # summerize_contents(crew, storyfile, logfile, summary)


# 이야기 생성 함수


def story_creation(crew, theme, storyfile, logfile, i):

    # 스토리 파일 읽고 이야기 생성
    with open(storyfile, "r", encoding="utf-8") as file:
        previous_story = file.read()

    crew.tasks = [story_creation_task]
    story_result = crew.kickoff(
        inputs={"theme": theme, "previous_story": previous_story}
    )
    story_text = f"## 상황 {i+1}:\n{story_result}\n\n"

    # 초기 캐릭터 만들때 파일을 생성해서 그냥 a로
    with open(logfile, "a", encoding="utf-8") as file:
        file.write(story_text)
    with open(storyfile, "a", encoding="utf-8") as file:
        file.write(story_text)
    return story_result


# 선택지 생성 함수


def create_options(crew, theme, storyfile, logfile):

    # 요약 파일 및 방금 생성된 이야기

    with open(storyfile, "r", encoding="utf") as file:
        previous_story = file.read()

    crew.tasks = [choice_creation_task]
    choices_creation = crew.kickoff(
        inputs={"theme": theme, "previous_story": previous_story}
    )
    story_text = f"{choices_creation}\n\n\n"

    # 로그에 저장
    with open(logfile, "a", encoding="utf-8") as file:
        file.write(story_text)

    return choices_creation


# 사용자 선택 함수


def user_selection(choices_creation, storyfile, logfile, i):
    choice = input(
        "1부터 5까지의 숫자 중 하나를 선택하거나 원하는 대로 스토리를 적으세요: "
    )
    story_text = f"## 사용자 선택 : {choice}\n\n\n"

    # 선택지를 고른 경우
    if len(choice) == 1:
        ## 숫자 추출
        choices_lines = choices_creation.split("\n")
        line = ""
        for i in choices_lines:
            if i.startswith(f"{choice}."):
                line = f"{i}\n\n\n"
    # 직접 글로 입력한 경우
    else:
        line = choice

    # 로그에 사용자가 선택한 숫자 추가
    with open(logfile, "a", encoding="utf-8") as file:
        file.write(story_text)

    # story.md 에 선택한 내용 추가
    with open(storyfile, "a", encoding="utf-8") as file:
        file.write(line)

    # 5번을 선택하면 이야기를 마무리 지음
    if choice == "5":
        return False

    return True


# #내용 요약
# def summerize_contents(crew, storyfile, logfile, summary):
#         with open(storyfile, 'r', encoding="utf") as file:
#             previous_story = file.read()
#         crew.tasks = [story_summerization_task]
#         summerize_story = crew.kickoff(inputs={'previous_story': previous_story})
#         # 요약 결과를 파일에 저장
#         with open(summary, 'w', encoding='utf-8') as file:
#              file.write(summerize_story)
# 크루 실행 및 결과 출력

# %%
execute_story(story_crew, "카페")
# Out:
#  [DEBUG]: == Working Agent: 이야기의 주인공 생성자
#  [INFO]: == Starting Task: 카페 배경에 어울리는 인물 한명을 생성합니다. 우선 그 인물의 직업을 5개정도 생성하고 무작위로 하나를 선택합니다. 그 인물의 인적사항을 출력합니다
#  [DEBUG]: == [이야기의 주인공 생성자] Task output: 당신은 '자유로운 영혼의 작가'입니다.
#
# **이름:**  윤서현
#
# **나이:** 28세
#
# **성별:** 여성
#
# **외모:** 긴 생머리에 푸른 눈을 가진, 서구적인 외모를 가졌습니다. 늘 편안한 옷차림을 선호하며, 낡은 가죽 가방을 늘 곁에 두고 다닙니다.
#
# **성격:**  자유롭고 낙천적인 성격으로, 세상에 대한 호기심이 많습니다. 혼자만의 시간을 즐기는 것을 좋아하며, 카페에서 글을 쓰는 것을 즐깁니다. 때로는 조용하고 내성적인 모습을 보이기도 하지만, 친해지면 유머 감각 넘치는 사람입니다.
#
# **특징:**  항상 노트북과 함께 다니며, 카페에서 글을 쓸 때는 커피보다는 따뜻한 차를 즐겨 마십니다. 좋아하는 작가는 어니스트 헤밍웨이와 톨스토이입니다.
#
# **카페에서의 모습:**  창가 쪽 테이블에 앉아 노트북으로 글을 쓰거나, 책을 읽으며 시간을 보냅니다. 혼자 조용히 있는 것을 좋아하지만, 가끔 다른 손님들과 이야기를 나누기도 합니다.
#
#
#  [DEBUG]: == Working Agent: 이야기 생성자
#  [INFO]: == Starting Task: 1. 나열된 규칙을 지키면서 카페 배경에 자연스럽고 당신은 '자유로운 영혼의 작가'입니다.
#
# **이름:**  윤서현
#
# **나이:** 28세
#
# **성별:** 여성
#
# **외모:** 긴 생머리에 푸른 눈을 가진, 서구적인 외모를 가졌습니다. 늘 편안한 옷차림을 선호하며, 낡은 가죽 가방을 늘 곁에 두고 다닙니다.
#
# **성격:**  자유롭고 낙천적인 성격으로, 세상에 대한 호기심이 많습니다. 혼자만의 시간을 즐기는 것을 좋아하며, 카페에서 글을 쓰는 것을 즐깁니다. 때로는 조용하고 내성적인 모습을 보이기도 하지만, 친해지면 유머 감각 넘치는 사람입니다.
#
# **특징:**  항상 노트북과 함께 다니며, 카페에서 글을 쓸 때는 커피보다는 따뜻한 차를 즐겨 마십니다. 좋아하는 작가는 어니스트 헤밍웨이와 톨스토이입니다.
#
# **카페에서의 모습:**  창가 쪽 테이블에 앉아 노트북으로 글을 쓰거나, 책을 읽으며 시간을 보냅니다. 혼자 조용히 있는 것을 좋아하지만, 가끔 다른 손님들과 이야기를 나누기도 합니다.
# 에 이어지는 새로운 상황을 생성하세요.
# 규칙 1. 주인공의 선택을 마음대로 결정해서는 안됩니다.
# 규칙 2. 주인공이 처한 상황, 다른 인물이 걸어오는 대사 등을 포함합니다.
# 규칙 3. 이야기는 주인공이 어떤 선택을 해야 할 상황에서 끝나도록 하세요.
# 규칙 4. 주인공이 어떤 행동을 할지 질문하거나 궁금해하지 말고, 주인공의 결정을 요구하는 문장 없이 스토리만 생성합니다.
# 규칙 5. 상황을 마무리하는 문장으로 질문이나 선택을 요구하는 문장이 포함되지 않도록 하세요.
#  [DEBUG]: == [이야기 생성자] Task output: 윤서현은 창가 쪽 테이블에 앉아 노트북 화면을 응시하며 글을 쓰고 있었다. 따뜻한 차 향이 코끝을 스치며 집중력을 높여주었다. 잠시 후, 옆 테이블에 앉은 남자가 윤서현에게 다가왔다. 그는 짙은 갈색 눈으로 윤서현을 빤히 바라보며 말했다. "혹시, 작가님이세요?" 그의 목소리는 부드러웠지만, 눈빛은 날카로웠다. 윤서현은 놀란 듯 눈을 크게 뜨며 남자를 바라보았다. 남자는 웃으며 자신의 손에 들린 책을 내밀었다. "제가 좋아하는 작가님 책이에요. 혹시 사인을 받을 수 있을까요?" 윤서현은 남자의 손에 들린 책을 보았다. 자신의 책이었다.
#
#
#  [DEBUG]: == Working Agent: 선택지 제공자
#  [INFO]: == Starting Task: 이야기 상황에 맞는 4가지 선택지를 생성하세요. 각 선택지는 이야기와 관련이 있어야 합니다.당신은 '자유로운 영혼의 작가'입니다.
#
# **이름:**  윤서현
#
# **나이:** 28세
#
# **성별:** 여성
#
# **외모:** 긴 생머리에 푸른 눈을 가진, 서구적인 외모를 가졌습니다. 늘 편안한 옷차림을 선호하며, 낡은 가죽 가방을 늘 곁에 두고 다닙니다.
#
# **성격:**  자유롭고 낙천적인 성격으로, 세상에 대한 호기심이 많습니다. 혼자만의 시간을 즐기는 것을 좋아하며, 카페에서 글을 쓰는 것을 즐깁니다. 때로는 조용하고 내성적인 모습을 보이기도 하지만, 친해지면 유머 감각 넘치는 사람입니다.
#
# **특징:**  항상 노트북과 함께 다니며, 카페에서 글을 쓸 때는 커피보다는 따뜻한 차를 즐겨 마십니다. 좋아하는 작가는 어니스트 헤밍웨이와 톨스토이입니다.
#
# **카페에서의 모습:**  창가 쪽 테이블에 앉아 노트북으로 글을 쓰거나, 책을 읽으며 시간을 보냅니다. 혼자 조용히 있는 것을 좋아하지만, 가끔 다른 손님들과 이야기를 나누기도 합니다.
# ## 상황 1:
# 윤서현은 창가 쪽 테이블에 앉아 노트북 화면을 응시하며 글을 쓰고 있었다. 따뜻한 차 향이 코끝을 스치며 집중력을 높여주었다. 잠시 후, 옆 테이블에 앉은 남자가 윤서현에게 다가왔다. 그는 짙은 갈색 눈으로 윤서현을 빤히 바라보며 말했다. "혹시, 작가님이세요?" 그의 목소리는 부드러웠지만, 눈빛은 날카로웠다. 윤서현은 놀란 듯 눈을 크게 뜨며 남자를 바라보았다. 남자는 웃으며 자신의 손에 들린 책을 내밀었다. "제가 좋아하는 작가님 책이에요. 혹시 사인을 받을 수 있을까요?" 윤서현은 남자의 손에 들린 책을 보았다. 자신의 책이었다.
#
# 와 이어지며, 마지막으로 제시된 상황에 맞는 선택지를 생성하세요.
# 5번째 선택지는 고정적으로 '여기서 이야기의 마무리합니다.'입니다.
#  [DEBUG]: == [선택지 제공자] Task output: 1. "네, 맞아요. 제 책이네요. 사인은 흔쾌히 해드리겠어요. 어떤 책인가요?" - 윤서현은 밝게 웃으며 남자에게 책을 건네받는다.
# 2. "아, 네... 맞아요. 근데 사인은... 음..." - 윤서현은 당황하며 망설인다.
# 3. "죄송하지만, 지금은 글쓰기에 집중하고 싶어요." - 윤서현은 냉정하게 거절한다.
# 4. "혹시 제 글을 좋아하시나요? 어떤 부분이 좋으셨는지 궁금해요." - 윤서현은 남자의 호기심을 자극하며 대화를 이어나간다.
#
#
#  [DEBUG]: == Working Agent: 이야기 생성자
#  [INFO]: == Starting Task: 1. 나열된 규칙을 지키면서 카페 배경에 자연스럽고 당신은 '자유로운 영혼의 작가'입니다.
#
# **이름:**  윤서현
#
# **나이:** 28세
#
# **성별:** 여성
#
# **외모:** 긴 생머리에 푸른 눈을 가진, 서구적인 외모를 가졌습니다. 늘 편안한 옷차림을 선호하며, 낡은 가죽 가방을 늘 곁에 두고 다닙니다.
#
# **성격:**  자유롭고 낙천적인 성격으로, 세상에 대한 호기심이 많습니다. 혼자만의 시간을 즐기는 것을 좋아하며, 카페에서 글을 쓰는 것을 즐깁니다. 때로는 조용하고 내성적인 모습을 보이기도 하지만, 친해지면 유머 감각 넘치는 사람입니다.
#
# **특징:**  항상 노트북과 함께 다니며, 카페에서 글을 쓸 때는 커피보다는 따뜻한 차를 즐겨 마십니다. 좋아하는 작가는 어니스트 헤밍웨이와 톨스토이입니다.
#
# **카페에서의 모습:**  창가 쪽 테이블에 앉아 노트북으로 글을 쓰거나, 책을 읽으며 시간을 보냅니다. 혼자 조용히 있는 것을 좋아하지만, 가끔 다른 손님들과 이야기를 나누기도 합니다.
# ## 상황 1:
# 윤서현은 창가 쪽 테이블에 앉아 노트북 화면을 응시하며 글을 쓰고 있었다. 따뜻한 차 향이 코끝을 스치며 집중력을 높여주었다. 잠시 후, 옆 테이블에 앉은 남자가 윤서현에게 다가왔다. 그는 짙은 갈색 눈으로 윤서현을 빤히 바라보며 말했다. "혹시, 작가님이세요?" 그의 목소리는 부드러웠지만, 눈빛은 날카로웠다. 윤서현은 놀란 듯 눈을 크게 뜨며 남자를 바라보았다. 남자는 웃으며 자신의 손에 들린 책을 내밀었다. "제가 좋아하는 작가님 책이에요. 혹시 사인을 받을 수 있을까요?" 윤서현은 남자의 손에 들린 책을 보았다. 자신의 책이었다.
#
# 1. "네, 맞아요. 제 책이네요. 사인은 흔쾌히 해드리겠어요. 어떤 책인가요?" - 윤서현은 밝게 웃으며 남자에게 책을 건네받는다.
#
#
# 에 이어지는 새로운 상황을 생성하세요.
# 규칙 1. 주인공의 선택을 마음대로 결정해서는 안됩니다.
# 규칙 2. 주인공이 처한 상황, 다른 인물이 걸어오는 대사 등을 포함합니다.
# 규칙 3. 이야기는 주인공이 어떤 선택을 해야 할 상황에서 끝나도록 하세요.
# 규칙 4. 주인공이 어떤 행동을 할지 질문하거나 궁금해하지 말고, 주인공의 결정을 요구하는 문장 없이 스토리만 생성합니다.
# 규칙 5. 상황을 마무리하는 문장으로 질문이나 선택을 요구하는 문장이 포함되지 않도록 하세요.
#  [DEBUG]: == [이야기 생성자] Task output: "아, 이 책이요. '잃어버린 시간을 찾아서'라는 제목의 소설이에요. 작가님의 문체가 정말 마음에 들어서 밤새도록 읽었어요." 남자는 책을 내려놓으며 윤서현을 빤히 바라보았다. 윤서현은 남자의 눈빛에 묘한 긴장감을 느꼈다. 그때, 카페 문이 열리며 낯선 남자가 들어왔다. 그는 윤서현을 발견하자마자 굳은 표정으로 그녀에게 다가왔다. "윤서현 씨, 혹시 시간 좀 내주시겠어요?" 그의 목소리는 차가웠고, 눈빛은 날카로웠다. 윤서현은 옆 테이블 남자와 낯선 남자의 시선이 엇갈리는 것을 보았다.
#
#
#  [DEBUG]: == Working Agent: 선택지 제공자
#  [INFO]: == Starting Task: 이야기 상황에 맞는 4가지 선택지를 생성하세요. 각 선택지는 이야기와 관련이 있어야 합니다.당신은 '자유로운 영혼의 작가'입니다.
#
# **이름:**  윤서현
#
# **나이:** 28세
#
# **성별:** 여성
#
# **외모:** 긴 생머리에 푸른 눈을 가진, 서구적인 외모를 가졌습니다. 늘 편안한 옷차림을 선호하며, 낡은 가죽 가방을 늘 곁에 두고 다닙니다.
#
# **성격:**  자유롭고 낙천적인 성격으로, 세상에 대한 호기심이 많습니다. 혼자만의 시간을 즐기는 것을 좋아하며, 카페에서 글을 쓰는 것을 즐깁니다. 때로는 조용하고 내성적인 모습을 보이기도 하지만, 친해지면 유머 감각 넘치는 사람입니다.
#
# **특징:**  항상 노트북과 함께 다니며, 카페에서 글을 쓸 때는 커피보다는 따뜻한 차를 즐겨 마십니다. 좋아하는 작가는 어니스트 헤밍웨이와 톨스토이입니다.
#
# **카페에서의 모습:**  창가 쪽 테이블에 앉아 노트북으로 글을 쓰거나, 책을 읽으며 시간을 보냅니다. 혼자 조용히 있는 것을 좋아하지만, 가끔 다른 손님들과 이야기를 나누기도 합니다.
# ## 상황 1:
# 윤서현은 창가 쪽 테이블에 앉아 노트북 화면을 응시하며 글을 쓰고 있었다. 따뜻한 차 향이 코끝을 스치며 집중력을 높여주었다. 잠시 후, 옆 테이블에 앉은 남자가 윤서현에게 다가왔다. 그는 짙은 갈색 눈으로 윤서현을 빤히 바라보며 말했다. "혹시, 작가님이세요?" 그의 목소리는 부드러웠지만, 눈빛은 날카로웠다. 윤서현은 놀란 듯 눈을 크게 뜨며 남자를 바라보았다. 남자는 웃으며 자신의 손에 들린 책을 내밀었다. "제가 좋아하는 작가님 책이에요. 혹시 사인을 받을 수 있을까요?" 윤서현은 남자의 손에 들린 책을 보았다. 자신의 책이었다.
#
# 1. "네, 맞아요. 제 책이네요. 사인은 흔쾌히 해드리겠어요. 어떤 책인가요?" - 윤서현은 밝게 웃으며 남자에게 책을 건네받는다.
#
#
# ## 상황 2:
# "아, 이 책이요. '잃어버린 시간을 찾아서'라는 제목의 소설이에요. 작가님의 문체가 정말 마음에 들어서 밤새도록 읽었어요." 남자는 책을 내려놓으며 윤서현을 빤히 바라보았다. 윤서현은 남자의 눈빛에 묘한 긴장감을 느꼈다. 그때, 카페 문이 열리며 낯선 남자가 들어왔다. 그는 윤서현을 발견하자마자 굳은 표정으로 그녀에게 다가왔다. "윤서현 씨, 혹시 시간 좀 내주시겠어요?" 그의 목소리는 차가웠고, 눈빛은 날카로웠다. 윤서현은 옆 테이블 남자와 낯선 남자의 시선이 엇갈리는 것을 보았다.
#
# 와 이어지며, 마지막으로 제시된 상황에 맞는 선택지를 생성하세요.
# 5번째 선택지는 고정적으로 '여기서 이야기의 마무리합니다.'입니다.
#  [DEBUG]: == [선택지 제공자] Task output: 1. "죄송하지만, 지금은 바빠요. 나중에 연락 주세요." - 윤서현은 낯선 남자에게 차갑게 말하며 옆 테이블 남자에게 미소를 보낸다.
# 2. "무슨 일이세요? 혹시 아는 사람이신가요?" - 윤서현은 낯선 남자에게 질문하며 옆 테이블 남자의 반응을 살핀다.
# 3. "잠시만요. 옆에 분과 얘기 좀 하고 다시 말씀드릴게요." - 윤서현은 낯선 남자에게 말하며 옆 테이블 남자에게 먼저 다가간다.
# 4. "저, 혹시 두 분 아시는 사이세요?" - 윤서현은 낯선 남자와 옆 테이블 남자를 번갈아 보며 조심스럽게 질문한다.
# 5. 여기서 이야기의 마무리합니다.
#
#
#  [DEBUG]: == Working Agent: 이야기 생성자
#  [INFO]: == Starting Task: 1. 나열된 규칙을 지키면서 카페 배경에 자연스럽고 당신은 '자유로운 영혼의 작가'입니다.
#
# **이름:**  윤서현
#
# **나이:** 28세
#
# **성별:** 여성
#
# **외모:** 긴 생머리에 푸른 눈을 가진, 서구적인 외모를 가졌습니다. 늘 편안한 옷차림을 선호하며, 낡은 가죽 가방을 늘 곁에 두고 다닙니다.
#
# **성격:**  자유롭고 낙천적인 성격으로, 세상에 대한 호기심이 많습니다. 혼자만의 시간을 즐기는 것을 좋아하며, 카페에서 글을 쓰는 것을 즐깁니다. 때로는 조용하고 내성적인 모습을 보이기도 하지만, 친해지면 유머 감각 넘치는 사람입니다.
#
# **특징:**  항상 노트북과 함께 다니며, 카페에서 글을 쓸 때는 커피보다는 따뜻한 차를 즐겨 마십니다. 좋아하는 작가는 어니스트 헤밍웨이와 톨스토이입니다.
#
# **카페에서의 모습:**  창가 쪽 테이블에 앉아 노트북으로 글을 쓰거나, 책을 읽으며 시간을 보냅니다. 혼자 조용히 있는 것을 좋아하지만, 가끔 다른 손님들과 이야기를 나누기도 합니다.
# ## 상황 1:
# 윤서현은 창가 쪽 테이블에 앉아 노트북 화면을 응시하며 글을 쓰고 있었다. 따뜻한 차 향이 코끝을 스치며 집중력을 높여주었다. 잠시 후, 옆 테이블에 앉은 남자가 윤서현에게 다가왔다. 그는 짙은 갈색 눈으로 윤서현을 빤히 바라보며 말했다. "혹시, 작가님이세요?" 그의 목소리는 부드러웠지만, 눈빛은 날카로웠다. 윤서현은 놀란 듯 눈을 크게 뜨며 남자를 바라보았다. 남자는 웃으며 자신의 손에 들린 책을 내밀었다. "제가 좋아하는 작가님 책이에요. 혹시 사인을 받을 수 있을까요?" 윤서현은 남자의 손에 들린 책을 보았다. 자신의 책이었다.
#
# 1. "네, 맞아요. 제 책이네요. 사인은 흔쾌히 해드리겠어요. 어떤 책인가요?" - 윤서현은 밝게 웃으며 남자에게 책을 건네받는다.
#
#
# ## 상황 2:
# "아, 이 책이요. '잃어버린 시간을 찾아서'라는 제목의 소설이에요. 작가님의 문체가 정말 마음에 들어서 밤새도록 읽었어요." 남자는 책을 내려놓으며 윤서현을 빤히 바라보았다. 윤서현은 남자의 눈빛에 묘한 긴장감을 느꼈다. 그때, 카페 문이 열리며 낯선 남자가 들어왔다. 그는 윤서현을 발견하자마자 굳은 표정으로 그녀에게 다가왔다. "윤서현 씨, 혹시 시간 좀 내주시겠어요?" 그의 목소리는 차가웠고, 눈빛은 날카로웠다. 윤서현은 옆 테이블 남자와 낯선 남자의 시선이 엇갈리는 것을 보았다.
#
# 2. "무슨 일이세요? 혹시 아는 사람이신가요?" - 윤서현은 낯선 남자에게 질문하며 옆 테이블 남자의 반응을 살핀다.
#
#
# 에 이어지는 새로운 상황을 생성하세요.
# 규칙 1. 주인공의 선택을 마음대로 결정해서는 안됩니다.
# 규칙 2. 주인공이 처한 상황, 다른 인물이 걸어오는 대사 등을 포함합니다.
# 규칙 3. 이야기는 주인공이 어떤 선택을 해야 할 상황에서 끝나도록 하세요.
# 규칙 4. 주인공이 어떤 행동을 할지 질문하거나 궁금해하지 말고, 주인공의 결정을 요구하는 문장 없이 스토리만 생성합니다.
# 규칙 5. 상황을 마무리하는 문장으로 질문이나 선택을 요구하는 문장이 포함되지 않도록 하세요.
#  [DEBUG]: == [이야기 생성자] Task output: 옆 테이블 남자는 낯선 남자의 등장에 놀란 듯 눈살을 찌푸렸다. "혹시 아시는 분인가요?" 그는 윤서현에게 물었지만, 윤서현은 대답 대신 낯선 남자를 쳐다보았다. 낯선 남자는 차가운 눈빛으로 윤서현을 응시하며 말했다. "개인적인 이야기가 있어요. 잠시 시간 내주시죠." 윤서현은 옆 테이블 남자의 시선을 느끼며 망설였다. 옆 테이블 남자는 윤서현의 망설임을 알아챈 듯 웃으며 말했다. "저는 괜찮아요. 작가님의 시간이 소중하니까요." 그는 부드러운 목소리로 말했지만, 그의 눈빛은 여전히 날카로웠다. 윤서현은 옆 테이블 남자와 낯선 남자 사이에서 갈등했다.
#
#
#  [DEBUG]: == Working Agent: 선택지 제공자
#  [INFO]: == Starting Task: 이야기 상황에 맞는 4가지 선택지를 생성하세요. 각 선택지는 이야기와 관련이 있어야 합니다.당신은 '자유로운 영혼의 작가'입니다.
#
# **이름:**  윤서현
#
# **나이:** 28세
#
# **성별:** 여성
#
# **외모:** 긴 생머리에 푸른 눈을 가진, 서구적인 외모를 가졌습니다. 늘 편안한 옷차림을 선호하며, 낡은 가죽 가방을 늘 곁에 두고 다닙니다.
#
# **성격:**  자유롭고 낙천적인 성격으로, 세상에 대한 호기심이 많습니다. 혼자만의 시간을 즐기는 것을 좋아하며, 카페에서 글을 쓰는 것을 즐깁니다. 때로는 조용하고 내성적인 모습을 보이기도 하지만, 친해지면 유머 감각 넘치는 사람입니다.
#
# **특징:**  항상 노트북과 함께 다니며, 카페에서 글을 쓸 때는 커피보다는 따뜻한 차를 즐겨 마십니다. 좋아하는 작가는 어니스트 헤밍웨이와 톨스토이입니다.
#
# **카페에서의 모습:**  창가 쪽 테이블에 앉아 노트북으로 글을 쓰거나, 책을 읽으며 시간을 보냅니다. 혼자 조용히 있는 것을 좋아하지만, 가끔 다른 손님들과 이야기를 나누기도 합니다.
# ## 상황 1:
# 윤서현은 창가 쪽 테이블에 앉아 노트북 화면을 응시하며 글을 쓰고 있었다. 따뜻한 차 향이 코끝을 스치며 집중력을 높여주었다. 잠시 후, 옆 테이블에 앉은 남자가 윤서현에게 다가왔다. 그는 짙은 갈색 눈으로 윤서현을 빤히 바라보며 말했다. "혹시, 작가님이세요?" 그의 목소리는 부드러웠지만, 눈빛은 날카로웠다. 윤서현은 놀란 듯 눈을 크게 뜨며 남자를 바라보았다. 남자는 웃으며 자신의 손에 들린 책을 내밀었다. "제가 좋아하는 작가님 책이에요. 혹시 사인을 받을 수 있을까요?" 윤서현은 남자의 손에 들린 책을 보았다. 자신의 책이었다.
#
# 1. "네, 맞아요. 제 책이네요. 사인은 흔쾌히 해드리겠어요. 어떤 책인가요?" - 윤서현은 밝게 웃으며 남자에게 책을 건네받는다.
#
#
# ## 상황 2:
# "아, 이 책이요. '잃어버린 시간을 찾아서'라는 제목의 소설이에요. 작가님의 문체가 정말 마음에 들어서 밤새도록 읽었어요." 남자는 책을 내려놓으며 윤서현을 빤히 바라보았다. 윤서현은 남자의 눈빛에 묘한 긴장감을 느꼈다. 그때, 카페 문이 열리며 낯선 남자가 들어왔다. 그는 윤서현을 발견하자마자 굳은 표정으로 그녀에게 다가왔다. "윤서현 씨, 혹시 시간 좀 내주시겠어요?" 그의 목소리는 차가웠고, 눈빛은 날카로웠다. 윤서현은 옆 테이블 남자와 낯선 남자의 시선이 엇갈리는 것을 보았다.
#
# 2. "무슨 일이세요? 혹시 아는 사람이신가요?" - 윤서현은 낯선 남자에게 질문하며 옆 테이블 남자의 반응을 살핀다.
#
#
# ## 상황 3:
# 옆 테이블 남자는 낯선 남자의 등장에 놀란 듯 눈살을 찌푸렸다. "혹시 아시는 분인가요?" 그는 윤서현에게 물었지만, 윤서현은 대답 대신 낯선 남자를 쳐다보았다. 낯선 남자는 차가운 눈빛으로 윤서현을 응시하며 말했다. "개인적인 이야기가 있어요. 잠시 시간 내주시죠." 윤서현은 옆 테이블 남자의 시선을 느끼며 망설였다. 옆 테이블 남자는 윤서현의 망설임을 알아챈 듯 웃으며 말했다. "저는 괜찮아요. 작가님의 시간이 소중하니까요." 그는 부드러운 목소리로 말했지만, 그의 눈빛은 여전히 날카로웠다. 윤서현은 옆 테이블 남자와 낯선 남자 사이에서 갈등했다.
#
# 와 이어지며, 마지막으로 제시된 상황에 맞는 선택지를 생성하세요.
# 5번째 선택지는 고정적으로 '여기서 이야기의 마무리합니다.'입니다.
#  [DEBUG]: == [선택지 제공자] Task output: 1. "죄송하지만, 지금은 시간이 없어요. 나중에 연락 주시겠어요?" - 윤서현은 낯선 남자에게 시간이 없다고 말하며 옆 테이블 남자에게 미소를 보낸다.
# 2. "잠시만요. 옆 테이블 분과 먼저 이야기를 마무리해야 할 것 같아요." - 윤서현은 낯선 남자에게 잠시 기다려달라고 말하며 옆 테이블 남자에게 이야기를 계속 이어나간다.
# 3. "무슨 일인지 말씀해주세요. 혹시 제 글에 대한 이야기인가요?" - 윤서현은 낯선 남자에게 그의 의도를 묻는다.
# 4. "죄송하지만, 둘 다 시간을 내드릴 수 없을 것 같아요. 저는 지금 글쓰기에 집중해야 해요." - 윤서현은 둘에게 정중하게 거절하며 다시 글쓰기에 집중한다.
#
#
#  [DEBUG]: == Working Agent: 이야기 결말 생성자
#  [INFO]: == Starting Task: 당신은 '자유로운 영혼의 작가'입니다.
#
# **이름:**  윤서현
#
# **나이:** 28세
#
# **성별:** 여성
#
# **외모:** 긴 생머리에 푸른 눈을 가진, 서구적인 외모를 가졌습니다. 늘 편안한 옷차림을 선호하며, 낡은 가죽 가방을 늘 곁에 두고 다닙니다.
#
# **성격:**  자유롭고 낙천적인 성격으로, 세상에 대한 호기심이 많습니다. 혼자만의 시간을 즐기는 것을 좋아하며, 카페에서 글을 쓰는 것을 즐깁니다. 때로는 조용하고 내성적인 모습을 보이기도 하지만, 친해지면 유머 감각 넘치는 사람입니다.
#
# **특징:**  항상 노트북과 함께 다니며, 카페에서 글을 쓸 때는 커피보다는 따뜻한 차를 즐겨 마십니다. 좋아하는 작가는 어니스트 헤밍웨이와 톨스토이입니다.
#
# **카페에서의 모습:**  창가 쪽 테이블에 앉아 노트북으로 글을 쓰거나, 책을 읽으며 시간을 보냅니다. 혼자 조용히 있는 것을 좋아하지만, 가끔 다른 손님들과 이야기를 나누기도 합니다.
# ## 상황 1:
# 윤서현은 창가 쪽 테이블에 앉아 노트북 화면을 응시하며 글을 쓰고 있었다. 따뜻한 차 향이 코끝을 스치며 집중력을 높여주었다. 잠시 후, 옆 테이블에 앉은 남자가 윤서현에게 다가왔다. 그는 짙은 갈색 눈으로 윤서현을 빤히 바라보며 말했다. "혹시, 작가님이세요?" 그의 목소리는 부드러웠지만, 눈빛은 날카로웠다. 윤서현은 놀란 듯 눈을 크게 뜨며 남자를 바라보았다. 남자는 웃으며 자신의 손에 들린 책을 내밀었다. "제가 좋아하는 작가님 책이에요. 혹시 사인을 받을 수 있을까요?" 윤서현은 남자의 손에 들린 책을 보았다. 자신의 책이었다.
#
# 1. "네, 맞아요. 제 책이네요. 사인은 흔쾌히 해드리겠어요. 어떤 책인가요?" - 윤서현은 밝게 웃으며 남자에게 책을 건네받는다.
#
#
# ## 상황 2:
# "아, 이 책이요. '잃어버린 시간을 찾아서'라는 제목의 소설이에요. 작가님의 문체가 정말 마음에 들어서 밤새도록 읽었어요." 남자는 책을 내려놓으며 윤서현을 빤히 바라보았다. 윤서현은 남자의 눈빛에 묘한 긴장감을 느꼈다. 그때, 카페 문이 열리며 낯선 남자가 들어왔다. 그는 윤서현을 발견하자마자 굳은 표정으로 그녀에게 다가왔다. "윤서현 씨, 혹시 시간 좀 내주시겠어요?" 그의 목소리는 차가웠고, 눈빛은 날카로웠다. 윤서현은 옆 테이블 남자와 낯선 남자의 시선이 엇갈리는 것을 보았다.
#
# 2. "무슨 일이세요? 혹시 아는 사람이신가요?" - 윤서현은 낯선 남자에게 질문하며 옆 테이블 남자의 반응을 살핀다.
#
#
# ## 상황 3:
# 옆 테이블 남자는 낯선 남자의 등장에 놀란 듯 눈살을 찌푸렸다. "혹시 아시는 분인가요?" 그는 윤서현에게 물었지만, 윤서현은 대답 대신 낯선 남자를 쳐다보았다. 낯선 남자는 차가운 눈빛으로 윤서현을 응시하며 말했다. "개인적인 이야기가 있어요. 잠시 시간 내주시죠." 윤서현은 옆 테이블 남자의 시선을 느끼며 망설였다. 옆 테이블 남자는 윤서현의 망설임을 알아챈 듯 웃으며 말했다. "저는 괜찮아요. 작가님의 시간이 소중하니까요." 그는 부드러운 목소리로 말했지만, 그의 눈빛은 여전히 날카로웠다. 윤서현은 옆 테이블 남자와 낯선 남자 사이에서 갈등했다.
#
# 에 이어지는 결말을 생성하세요이야기가 마무리되는 느낌으로 되어야 합니다. '나의 이야기는 이제부터 시작될 것이다.' 등과 같이 새로운 이야기를 암시하는 내용은 포함하지 않습니다.
#  [DEBUG]: == [이야기 결말 생성자] Task output: 윤서현은 망설이는 표정으로 옆 테이블 남자를 바라보았다. 그의 부드러운 목소리는 그녀를 안심시켰지만, 그의 날카로운 눈빛은 그녀의 마음을 불안하게 만들었다. 낯선 남자는 윤서현의 망설임을 지켜보며 인내심이 바닥나기 시작했다. "시간이 없어요. 빨리 결정하세요." 그의 목소리는 차가웠다. 윤서현은 숨을 크게 들이쉬고 두 남자를 번갈아 보았다. 그녀는 옆 테이블 남자의 팬심이 진심임을 느꼈지만, 낯선 남자의 눈빛에는 무언가 숨겨진 비밀이 있는 것 같았다.
#
# 결국 윤서현은 낯선 남자를 따라 카페 밖으로 나섰다. 옆 테이블 남자는 그녀를 붙잡으려는 듯 했지만, 그녀는 그의 손길을 피하며 낯선 남자를 따라갔다. 낯선 남자는 차가운 표정으로 그녀를 데리고 골목길로 들어섰다. 그는 그녀를 멈춰 세우고, 차가운 목소리로 말했다. "당신은 내가 누군지 알고 있지. 그리고 내가 왜 당신을 찾았는지도 알고 있을 거야." 윤서현은 그의 말에 놀랐다. 그녀는 그를 전혀 알지 못했지만, 그의 눈빛에는 그녀를 꿰뚫어 보는 듯한 힘이 느껴졌다. "무슨 말씀인지 모르겠어요." 그녀는 떨리는 목소리로 대답했다. 낯선 남자는 웃으며 그녀의 손목을 잡았다. "곧 알게 될 거야. 당신의 이야기는 이제부터 시작될 거니까." 그의 손은 차가웠지만, 그의 눈빛은 뜨거웠다. 윤서현은 그를 따라 어둠 속으로 사라졌다.
